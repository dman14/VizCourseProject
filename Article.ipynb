# %% [markdown]
# # Exploring the new Economy of Europe

# %% [markdown]
# ## A look into the Covid-19's aftermath and the effects of it upon Europe's Economy

# %% [markdown]
# ![alt text](https://miro.medium.com/max/7000/1*IzrcG5VGKLYoISN4jKye6A.jpeg)
#   Image from: https://www.pexels.com/de-de/foto/nummern-notfall-alarm-warnung-3970330/

# %% [markdown]
# ## Introduction

# %% [markdown]
# **What is the state of today?**
#
# The middle of 2020 is approaching, and almost half of this time people have been staying inside, barely leaving the house for necessities or, in some cases, for their job.
#
# This is the state of today, still in quarantine, but at least slowly being able to see the end of it, as multiple countries decided to throttle back the restrictions, and with patience, letting people exit their homes again.
#
# Of course this is not without reason, as the epidemic is slowing down, and in Some bigger countries we're starting to see a downslope on the active cases.
#
# But even with this being said, the question is if we can already be happy that we passed and fought through it, or if there is more to come. Fewer people are getting infected, but to be able to achieve this, all the countries had to institute hard lockdowns, quarantines, and stop quite a lot of businesses from their activity, and this might be felt quite a bit in the next period.
#
# This is exactly what we're trying to look at in this article. How badly was Europe, at least, affected by this whole lockdown, and how hard will it be to come back to a state of normality.
#
# **data, data and more data**
#
# In order to be able to do this, we're going to need to look in some data, and see if we can get any hope from it. and for starters, it will be the dataset from Johns Hopkins University containing all numbers needed to be able to look into the Covid-19 situation.
#
# After that, we're going to analyze the World Economic Outlook (WEO) datasets from the International Monetary Fund (IMF) in order to see the effects.

# %% [markdown]
# ## Europe under Covid-19's grasp

# %% [markdown]
# **Current Situation**
#
# The coronavirus situation is changing everyday around Europe. Currently, more countries are exiting the lockdown in a slow manner and the governments are ready to tighten the rules if the number of cases suddenly increases. However, there are also other countries like Russia, where the number of cases is still continuing to increase.
#
# So far, in Europe, it has been interesting to observe that the number of cases in Western Europe is much higher than in Eastern Europe. There are different hypothesis for why is that the case and even one of them is that the vaccine Bacille Calmette-Guérin (BCG) is still used in most of the Eastern countries. The World Health Organization (WHO) has stated that ["there is no evidence that the BCG vaccine protects people against infection with COVID-19 virus"](https://www.who.int/news-room/commentaries/detail/bacille-calmette-gu%C3%A9rin-(bcg)-vaccination-and-covid-19). Clinical trials are underway to support that claim. Another thing is that emerging economies in Europe took more strict measures against the virus and acted earlier to reduce the spread.
#
# On the interactive maps below, we can see the total number of confirmed cases and number of deaths for each country until now. The exact number of cases/deaths for each country can be seen by hovering with the mouse.

# %% [markdown]
# On those two maps, we can see that Russia has the most number of cases until today and United Kingdom - the most number of deaths. If we exclude Russia, we can see how the Western and Eastern countries are separated as the Western countries are in darker red colour on the maps.
#
# **The Development of the virus**
#
# Another interesting thing that we can look at is how the number of cases and deaths increased over time, so we can see not only the current state but also how the numbers developed over time for each country. And this is what we can observe on the time-lapse below which shows how the number of deaths increase in respect of the total number of cases for each country. In addition, the circles are based on the size of each country's population and the countries with developed and emerging economies are colour coded in red and blue respectively.

# %% [markdown]
# We can see on the final frame of the time-lapse, that most of the developed countries are further to the right, with the exception of Turkey and Russia. In addition, if we zoom into the lower left corner, we can also observe that the countries that are a bit higher and to the right are also part of the developed economy countries like Portugal, Switzerland, Sweden, Netherlands and Belgium. It can be also observed that emerging economy countries with big population like Romania, Ukraine and Poland have also lower cases and deaths than the before mentioned developed ones.

# %% [markdown]
# ## Europe's Economy

# %% [markdown]
# **Economical Overview of Europe**
#
# To have a better overlook over the Europe's economy, IMF supplied quite a lot of data with everything related to it, such as gross domestic product, or GDP, GDP per capita, inflation percentages, unemployment rate, and so on. Included into this, besides the actual data until 2019, IMF provided their estimated values too for the end of 2020 and 2021, and updated this April.

# %%
# Out:
#           Click entry in the legend to selecte/deselect country, double click to isolate one entry

# %% [markdown]
# **What can we see from this?**
#
# Of course looking directly at all the data doesn't give us a lot of information, but analyzing it a bit further, we can see some details which are going to be addressed.

# %% [markdown]
# Firstly, even if it doesn't look that good for 2020, and overall having a loss in GDP by 6.611%, the predictions are that Europe's going to recover quite well after 2021, having an increase in GDP of 4.986%.

# %% [markdown]
# **The 2008**

# %% [markdown]
# This can be further compared with another crisis that happened not long ago, namly the Financial crisis of 2008, and at least in predictions, even though the fall was bigger as a lot of businesses had to shutdown, the estimate recovery is way faster then the one from 2008, presumembly not affecting the economy as bad as before.

# %% [markdown]
# **The differences in Europe**
#
# Economically speaking, Europe can be split into two parts, the Euro area, and Emerging and developing Europe. This split can be seen on IMF too, we're the data set of Euro zone contains bigger countries like Germany, Spain, Italy, etc. while in the Emerging and developing economies we can find countries such as Albania, Montenegro, Belarus, Poland, etc.

# %% [markdown]
# Interestingly enough, we can spot those countries on the map even by just plotting the percentage growth of the GDP per capita, as even the name implies(emerging and developing economies) the economy of such countries grow at a significantly higher rate than other fully developed ones.

# %% [markdown]
# This fact about the Developing economy countries in Europe can be seen in those times of economic downfall, as those countries, on average, did not get such a harsh fall as the Euro zone countries, and, presumably, will advance quite a bit faster after in 2021 too.

# %% [markdown]
# ## In Conclusion?

# %% [markdown]
# So after all this, what can we conclude?
#
# well, firstly we can see that even if it looks quite grim right now, economically wise, Europe will recover, and at a quite fast pace, faster then what we've seen before in 2008's economic crisis. Besides this, we've seen that actually the developing economies of Europe did not get such a big hit as other countries, some actually even registering [increases](https://insse.ro/cms/sites/default/files/com_presa/com_pdf/pib_tr1r2020.pdf). Another factor for this could actually be the increased number of both cases and deaths in the Euro zone countries.

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
